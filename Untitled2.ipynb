# %%
import psycopg2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7d2da0a5d979> in <module>
# ----> 1 import psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
# !pip install psycopg2
# Out:
# ...
#   Using cached psycopg2-2.8.6.tar.gz (383 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/himanibali/opt/anaconda3/bin/python -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/j1/k3mbh0vd2sx6dzzjkh9wgphr0000gn/T/pip-install-sqd_74hs/psycopg2_869c03636c7e4f23913556b9d4191694/setup.py'"'"'; __file__='"'"'/private/var/folders/j1/k3mbh0vd2sx6dzzjkh9wgphr0000gn/T/pip-install-sqd_74hs/psycopg2_869c03636c7e4f23913556b9d4191694/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/j1/k3mbh0vd2sx6dzzjkh9wgphr0000gn/T/pip-pip-egg-info-bkddbzb5
#          cwd: /private/var/folders/j1/k3mbh0vd2sx6dzzjkh9wgphr0000gn/T/pip-install-sqd_74hs/psycopg2_869c03636c7e4f23913556b9d4191694/
#     Complete output (23 lines):
#     running egg_info
# ...

# %%
pip install psycopg2-binary
# Out:
# ...
#      |████████████████████████████████| 1.5 MB 710 kB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=studentdb password=studnet")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fa405400a67a> in <module>
# ----> 1 conn = psycopg2.connect("host=127.0.0.1 dbname=studentdb password=studnet")
#
# NameError: name 'psycopg2' is not defined

# %%
conn = psycopg2-binary.connect("host=127.0.0.1 dbname=studentdb password=studnet")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-de23db1166a5> in <module>
# ----> 1 conn = psycopg2-binary.connect("host=127.0.0.1 dbname=studentdb password=studnet")
#
# NameError: name 'psycopg2' is not defined

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=studentdb user=student password=studnet")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-24726f5a5d62> in <module>
# ----> 1 conn = psycopg2.connect("host=127.0.0.1 dbname=studentdb user=student password=studnet")
#
# NameError: name 'psycopg2' is not defined

# %%
onn = psycopg2-binary.connect("host=127.0.0.1 dbname=studentdb user=student password=studnet")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1ccbd39c622c> in <module>
# ----> 1 onn = psycopg2-binary.connect("host=127.0.0.1 dbname=studentdb user=student password=studnet")
#
# NameError: name 'psycopg2' is not defined
